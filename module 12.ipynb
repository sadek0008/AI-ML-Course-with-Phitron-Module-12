# %%
print("i am student")
# Out:
# i am student

# %%
import pandas as pd 
df = pd.read_csv("student_data (1).csv")

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  ...  EnrollmentDate  Instructor    Location
# 0     PH1001       Alif Rahman                  85.0  ...      2024-01-15   Mr. Karim       Dhaka
# 1     PH1002     Fatima Akhter                  92.0  ...      2024-01-20   Ms. Salma  Chattogram
# 2     PH1003     Imran Hossain                  88.0  ...      2024-02-10   Mr. Karim       Dhaka
# 3     PH1004  Jannatul Ferdous                  78.0  ...      2024-02-12   Ms. Salma      Sylhet
# 4     PH1005       Kamal Uddin                   NaN  ...      2024-03-05   Mr. Karim  Chattogram
# 5     PH1006       Laila Begum                  75.0  ...      2024-03-08   Ms. Salma    Rajshahi
# 6     PH1007    Mahmudul Hasan                  80.0  ...      2024-04-01   Mr. Karim       Dhaka
# 7     PH1008       Nadia Islam                  81.0  ...      2024-04-22   Ms. Salma  Chattogram
# 8     PH1009        Omar Faruq                  72.0  ...      2024-05-16   Mr. David       Dhaka
# ...

# %%
names=df["FullName"]
print(type(names))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.loc[1]
# Out:
# StudentID                      PH1002
# FullName                Fatima Akhter
# Data Structure Marks             92.0
# Algorithm Marks                  92.0
# Python Marks                      NaN
# CompletionStatus          In Progress
# EnrollmentDate             2024-01-20
# Instructor                  Ms. Salma
# Location                   Chattogram
# Name: 1, dtype: object

# %%
df.loc[1:5,["FullName","Python Marks","Location"]]
# Out:
#            FullName  Python Marks    Location
# 1     Fatima Akhter           NaN  Chattogram
# 2     Imran Hossain          85.0       Dhaka
# 3  Jannatul Ferdous          82.0      Sylhet
# 4       Kamal Uddin          95.0  Chattogram
# 5       Laila Begum          78.0    Rajshahi

# %% [markdown]
# Changing Index and Columns and Iloc

# %%
df1 = df.set_index("StudentID")

# %%
df1
# Out:
#                    FullName  Data Structure Marks  Algorithm Marks  ...  EnrollmentDate Instructor    Location
# StudentID                                                           ...
# PH1001          Alif Rahman                  85.0             85.0  ...      2024-01-15  Mr. Karim       Dhaka
# PH1002        Fatima Akhter                  92.0             92.0  ...      2024-01-20  Ms. Salma  Chattogram
# PH1003        Imran Hossain                  88.0             88.0  ...      2024-02-10  Mr. Karim       Dhaka
# PH1004     Jannatul Ferdous                  78.0             78.0  ...      2024-02-12  Ms. Salma      Sylhet
# PH1005          Kamal Uddin                   NaN              NaN  ...      2024-03-05  Mr. Karim  Chattogram
# PH1006          Laila Begum                  75.0             75.0  ...      2024-03-08  Ms. Salma    Rajshahi
# PH1007       Mahmudul Hasan                  80.0             80.0  ...      2024-04-01  Mr. Karim       Dhaka
# ...

# %%
df.rename(columns={'FullName':'Full Name'})
# Out:
#    StudentID         Full Name  Data Structure Marks  ...  EnrollmentDate  Instructor    Location
# 0     PH1001       Alif Rahman                  85.0  ...      2024-01-15   Mr. Karim       Dhaka
# 1     PH1002     Fatima Akhter                  92.0  ...      2024-01-20   Ms. Salma  Chattogram
# 2     PH1003     Imran Hossain                  88.0  ...      2024-02-10   Mr. Karim       Dhaka
# 3     PH1004  Jannatul Ferdous                  78.0  ...      2024-02-12   Ms. Salma      Sylhet
# 4     PH1005       Kamal Uddin                   NaN  ...      2024-03-05   Mr. Karim  Chattogram
# 5     PH1006       Laila Begum                  75.0  ...      2024-03-08   Ms. Salma    Rajshahi
# 6     PH1007    Mahmudul Hasan                  80.0  ...      2024-04-01   Mr. Karim       Dhaka
# 7     PH1008       Nadia Islam                  81.0  ...      2024-04-22   Ms. Salma  Chattogram
# 8     PH1009        Omar Faruq                  72.0  ...      2024-05-16   Mr. David       Dhaka
# ...

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  ...  EnrollmentDate  Instructor    Location
# 1     PH1002     Fatima Akhter                  92.0  ...      2024-01-20   Ms. Salma  Chattogram
# 2     PH1003     Imran Hossain                  88.0  ...      2024-02-10   Mr. Karim       Dhaka
# 3     PH1004  Jannatul Ferdous                  78.0  ...      2024-02-12   Ms. Salma      Sylhet
# 4     PH1005       Kamal Uddin                   NaN  ...      2024-03-05   Mr. Karim  Chattogram
# 5     PH1006       Laila Begum                  75.0  ...      2024-03-08   Ms. Salma    Rajshahi
# 6     PH1007    Mahmudul Hasan                  80.0  ...      2024-04-01   Mr. Karim       Dhaka
# 7     PH1008       Nadia Islam                  81.0  ...      2024-04-22   Ms. Salma  Chattogram
# 8     PH1009        Omar Faruq                  72.0  ...      2024-05-16   Mr. David       Dhaka
# 9     PH1010      Priya Sharma                  89.0  ...      2024-05-20   Ms. Salma      Sylhet
# ...

# %%
df.loc[10,"FullName"]="sadekul islam"

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  ...  EnrollmentDate  Instructor    Location
# 1     PH1002     Fatima Akhter                  92.0  ...      2024-01-20   Ms. Salma  Chattogram
# 2     PH1003     Imran Hossain                  88.0  ...      2024-02-10   Mr. Karim       Dhaka
# 3     PH1004  Jannatul Ferdous                  78.0  ...      2024-02-12   Ms. Salma      Sylhet
# 4     PH1005       Kamal Uddin                   NaN  ...      2024-03-05   Mr. Karim  Chattogram
# 5     PH1006       Laila Begum                  75.0  ...      2024-03-08   Ms. Salma    Rajshahi
# 6     PH1007    Mahmudul Hasan                  80.0  ...      2024-04-01   Mr. Karim       Dhaka
# 7     PH1008       Nadia Islam                  81.0  ...      2024-04-22   Ms. Salma  Chattogram
# 8     PH1009        Omar Faruq                  72.0  ...      2024-05-16   Mr. David       Dhaka
# 9     PH1010      Priya Sharma                  89.0  ...      2024-05-20   Ms. Salma      Sylhet
# ...

# %%
for i,series in df.iterrows():
    print(f"{i} : {series}")
# Out:
# 1 : StudentID                      PH1002
# FullName                Fatima Akhter
# Data Structure Marks             92.0
# Algorithm Marks                  92.0
# Python Marks                      NaN
# CompletionStatus          In Progress
# EnrollmentDate             2024-01-20
# Instructor                  Ms. Salma
# Location                   Chattogram
# Name: 1, dtype: object
# 2 : StudentID                      PH1003
# FullName                Imran Hossain
# Data Structure Marks             88.0
# Algorithm Marks                  88.0
# Python Marks                     85.0
# CompletionStatus            Completed
# EnrollmentDate             2024-02-10
# Instructor                  Mr. Karim
# Location                        Dhaka
# Name: 2, dtype: object
# 3 : StudentID                         PH1004
# FullName                Jannatul Ferdous
# Data Structure Marks                78.0
# Algorithm Marks                     78.0
# Python Marks                        82.0
# ...

# %%
for i in df.itertuples():
    print(i)
# Out:
# Pandas(Index=1, StudentID='PH1002', FullName='Fatima Akhter', _3=92.0, _4=92.0, _5=nan, CompletionStatus='In Progress', EnrollmentDate='2024-01-20', Instructor='Ms. Salma', Location='Chattogram')
# Pandas(Index=2, StudentID='PH1003', FullName='Imran Hossain', _3=88.0, _4=88.0, _5=85.0, CompletionStatus='Completed', EnrollmentDate='2024-02-10', Instructor='Mr. Karim', Location='Dhaka')
# Pandas(Index=3, StudentID='PH1004', FullName='Jannatul Ferdous', _3=78.0, _4=78.0, _5=82.0, CompletionStatus='Completed', EnrollmentDate='2024-02-12', Instructor='Ms. Salma', Location='Sylhet')
# Pandas(Index=4, StudentID='PH1005', FullName='Kamal Uddin', _3=nan, _4=nan, _5=95.0, CompletionStatus='In Progress', EnrollmentDate='2024-03-05', Instructor='Mr. Karim', Location='Chattogram')
# Pandas(Index=5, StudentID='PH1006', FullName='Laila Begum', _3=75.0, _4=75.0, _5=78.0, CompletionStatus='Completed', EnrollmentDate='2024-03-08', Instructor='Ms. Salma', Location='Rajshahi')
# ...

# %%
df_sort = df.sort_values(["Python Marks"],ascending=False)

# %%
df_sort
# Out:
#    StudentID          FullName  Data Structure Marks  ...  EnrollmentDate  Instructor    Location
# 4     PH1005       Kamal Uddin                   NaN  ...      2024-03-05   Mr. Karim  Chattogram
# 16    PH1017       Afsana Mimi                  90.0  ...      2025-09-01   Mr. Karim       Dhaka
# 10    PH1011     sadekul islam                   NaN  ...      2024-06-11   Mr. Karim      Khulna
# 19    PH1020        Nasir Khan                  86.0  ...      2025-10-02   Ms. Salma       Dhaka
# 9     PH1010      Priya Sharma                  89.0  ...      2024-05-20   Ms. Salma      Sylhet
# 11    PH1012   Sadia Chowdhury                  85.0  ...      2024-06-14   Ms. Salma  Chattogram
# 2     PH1003     Imran Hossain                  88.0  ...      2024-02-10   Mr. Karim       Dhaka
# 17    PH1018       Babul Ahmed                  88.0  ...      2025-09-05   Ms. Salma      Sylhet
# 7     PH1008       Nadia Islam                  81.0  ...      2024-04-22   Ms. Salma  Chattogram
# ...

# %%
not_started = df.loc[df["CompletionStatus"]=="Not Started"]
not_started
# Out:
#    StudentID      FullName  Data Structure Marks  ...  EnrollmentDate  Instructor    Location
# 13    PH1014    Urmi Akter                   NaN  ...      2024-07-09   Ms. Salma    Rajshahi
# 18    PH1019  Faria Rahman                   NaN  ...      2025-09-15   Mr. David  Chattogram
#
# [2 rows x 9 columns]

# %%
started = df.loc[(df["CompletionStatus"]=="Completed") & (df["Python Marks"]>90)]
started
# Out:
#    StudentID     FullName  Data Structure Marks  Algorithm Marks  ...  CompletionStatus EnrollmentDate Instructor Location
# 16    PH1017  Afsana Mimi                  90.0             90.0  ...         Completed     2025-09-01  Mr. Karim    Dhaka
#
# [1 rows x 9 columns]
